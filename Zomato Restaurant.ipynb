# %% [markdown]
#  Zomato Restaurant

# %% [markdown]
# Project Description
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
# Problem statement :
# 1) Price range

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import sklearn

# %%
df=pd.read_csv('zomato.csv',encoding = "ISO-8859-1")

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# This Dataset contains 9551 rows and 21 columns.out of which 1 is target variable and remaining 20 are independent variables.
#
# EDA(Exploratory Data Analysis)

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %% [markdown]
# check the null values

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('\n')
# Out:
# 6317637     1
# 18254520    1
# 18462589    1
# 18336474    1
# 18336477    1
#            ..
# 313059      1
# 763         1
# 7557        1
# 525         1
# 5927402     1
# Name: Restaurant ID, Length: 9551, dtype: int64
#
#
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# Odeon Social                 1
# Johnny Rockets               1
# House of Commons             1
# HotMess                      1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7446, dtype: int64
#
#
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
#
#
# New Delhi           5473
# Gurgaon             1118
# Noida               1080
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# As we can see visualy that terre is no null values present in this dataset

# %%
df.nunique().to_frame('number of unique values')
# Out:
#                       number of unique values
# Restaurant ID                            9551
# Restaurant Name                          7446
# Country Code                               15
# City                                      141
# Address                                  8918
# Locality                                 1208
# Locality Verbose                         1265
# Longitude                                8120
# Latitude                                 8677
# Cuisines                                 1825
# Average Cost for two                      140
# Currency                                   12
# Has Table booking                           2
# Has Online delivery                         2
# Is delivering now                           2
# Switch to order menu                        1
# Price range                                 4
# Aggregate rating                           33
# Rating color                                6
# ...

# %% [markdown]
# Encoding Technique.

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=oe.fit_transform(df[i].values.reshape(-1,1))
        df

# %%
df
# Out:
#       Restaurant ID  Restaurant Name  Country Code   City  Address  Locality  \
# 0           6317637           3749.0           162   73.0   8685.0     171.0
# 1           6304287           3173.0           162   73.0   6055.0     593.0
# 2           6300002           2897.0           162   75.0   4684.0     308.0
# 3           6318506           4707.0           162   75.0   8690.0     862.0
# 4           6314302           5523.0           162   75.0   8689.0     862.0
# ...             ...              ...           ...    ...      ...       ...
# 9546        5915730           4443.0           208  140.0   5926.0     517.0
# 9547        5908749           1311.0           208  140.0   5962.0     552.0
# 9548        5915807           3069.0           208  140.0   5966.0     554.0
# 9549        5916112            513.0           208  140.0   5967.0     554.0
# 9550        5927402           7240.0           208  140.0   4258.0     670.0
#
# ...

# %% [markdown]
# Description of dataset(it gives the statistical summary of numerical columns)

# %%
df.describe()
# Out:
#        Restaurant ID  Restaurant Name  Country Code         City      Address  \
# count   9.551000e+03      9551.000000   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06      3653.204586     18.365616    78.301434  4542.439430
# std     8.791521e+06      2142.917876     56.750546    23.198915  2565.717005
# min     5.300000e+01         0.000000      1.000000     0.000000     0.000000
# 25%     3.019625e+05      1777.500000      1.000000    76.000000  2323.500000
# 50%     6.004089e+06      3595.000000      1.000000    88.000000  4610.000000
# 75%     1.835229e+07      5485.500000      1.000000    88.000000  6746.500000
# max     1.850065e+07      7445.000000    216.000000   140.000000  8917.000000
#
#           Locality  Locality Verbose    Longitude     Latitude     Cuisines  \
# count  9551.000000       9551.000000  9551.000000  9551.000000  9542.000000
# mean    658.128468        677.304994    64.126574    25.854381   989.163173
# ...

# %% [markdown]
# This is the Staststical information of the numerical columns.This summary of the dataset looks perfect.since there is no negative /invalid values present. here mean value is greater than Median so there is right skewness present in the dataset. and 75% and Max values are nearly same hence outliers are not present in the dataset.

# %% [markdown]
# Checking the counts of Targets

# %%
df['Price range'].value_counts()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %% [markdown]
# Data Visualization

# %%
ux=sns.countplot(x='Price range',data=df)
print(df['Price range'].value_counts())
plt.show()
# Out:
# 1    4444
# 2    3113
# 3    1408
# 4     586
# Name: Price range, dtype: int64

# %%
ux=sns.countplot(x='Country Code',data=df)
print(df['Country Code'].value_counts())
plt.show()
# Out:
# 1      8652
# 216     434
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64

# %%
ux=sns.countplot(x='Locality Verbose',data=df)
print(df['Locality Verbose'].value_counts())
plt.show()
# Out:
# 222.0     122
# 848.0      99
# 1024.0     87
# 280.0      86
# 805.0      85
#          ...
# 851.0       1
# 981.0       1
# 988.0       1
# 1109.0      1
# 681.0       1
# Name: Locality Verbose, Length: 1265, dtype: int64

# %%
ux=sns.countplot(x='Has Table booking',data=df)
print(df['Has Table booking'].value_counts())
plt.show()
# Out:
# 0.0    8393
# 1.0    1158
# Name: Has Table booking, dtype: int64

# %%
ux=sns.countplot(x='Locality',data=df)
print(df['Locality'].value_counts())
plt.show()
# Out:
# 216.0    122
# 835.0     99
# 971.0     87
# 274.0     86
# 639.0     85
#         ...
# 587.0      1
# 736.0      1
# 764.0      1
# 796.0      1
# 670.0      1
# Name: Locality, Length: 1208, dtype: int64

# %%
ux=sns.countplot(x='Longitude',data=df)
print(df['Longitude'].value_counts())
plt.show()
# Out:
# 0.000000     498
# 77.353663     19
# 77.230412     12
# 77.088688     10
# 77.251426      9
#             ...
# 77.227294      1
# 77.225420      1
# 77.230347      1
# 77.230578      1
# 29.026016      1
# Name: Longitude, Length: 8120, dtype: int64

# %%
ux=sns.countplot(x='Currency',data=df)
print(df['Currency'].value_counts())
plt.show()
# Out:
# 4.0     8652
# 2.0      482
# 7.0       80
# 1.0       60
# 3.0       60
# 9.0       60
# 6.0       40
# 11.0      34
# 0.0       22
# 5.0       21
# 8.0       20
# 10.0      20
# Name: Currency, dtype: int64

# %%
ux=sns.countplot(x='Has Online delivery',data=df)
print(df['Has Online delivery'].value_counts())
plt.show()
# Out:
# 0.0    7100
# 1.0    2451
# Name: Has Online delivery, dtype: int64

# %%
ux=sns.countplot(x='Aggregate rating',data=df)
print(df['Aggregate rating'].value_counts())
plt.show()
# Out:
# 0.0    2148
# 3.2     522
# 3.1     519
# 3.4     498
# 3.3     483
# 3.5     480
# 3.0     468
# 3.6     458
# 3.7     427
# 3.8     400
# 2.9     381
# 3.9     335
# 2.8     315
# 4.1     274
# 4.0     266
# 2.7     250
# 4.2     221
# 2.6     191
# 4.3     174
# 4.4     144
# 2.5     110
# 4.5      95
# 2.4      87
# 4.6      78
# 4.9      61
# 2.3      47
# 4.7      42
# 2.2      27
# 4.8      25
# 2.1      15
# 2.0       7
# 1.9       2
# 1.8       1
# Name: Aggregate rating, dtype: int64

# %%
ux=sns.countplot(x='Rating text',data=df)
print(df['Rating text'].value_counts())
plt.show()
# Out:
# 0.0    3737
# 3.0    2148
# 2.0    2100
# 5.0    1079
# 1.0     301
# 4.0     186
# Name: Rating text, dtype: int64

# %%
ux=sns.countplot(x='Votes',data=df)
print(df['Votes'].value_counts())
plt.show()
# Out:
# 0      1094
# 1       483
# 2       327
# 3       244
# 4       207
#        ...
# 615       1
# 538       1
# 823       1
# 650       1
# 901       1
# Name: Votes, Length: 1012, dtype: int64

# %% [markdown]
# Here we are checking outliers in the data.

# %%
df.plot(kind='box',subplots=True,layout=(6,4))
# Out:
# Restaurant ID               Axes(0.125,0.77;0.168478x0.11)
# Restaurant Name          Axes(0.327174,0.77;0.168478x0.11)
# Country Code             Axes(0.529348,0.77;0.168478x0.11)
# City                     Axes(0.731522,0.77;0.168478x0.11)
# Address                    Axes(0.125,0.638;0.168478x0.11)
# Locality                Axes(0.327174,0.638;0.168478x0.11)
# Locality Verbose        Axes(0.529348,0.638;0.168478x0.11)
# Longitude               Axes(0.731522,0.638;0.168478x0.11)
# Latitude                   Axes(0.125,0.506;0.168478x0.11)
# Cuisines                Axes(0.327174,0.506;0.168478x0.11)
# Average Cost for two    Axes(0.529348,0.506;0.168478x0.11)
# Currency                Axes(0.731522,0.506;0.168478x0.11)
# Has Table booking          Axes(0.125,0.374;0.168478x0.11)
# Has Online delivery     Axes(0.327174,0.374;0.168478x0.11)
# Is delivering now       Axes(0.529348,0.374;0.168478x0.11)
# Switch to order menu    Axes(0.731522,0.374;0.168478x0.11)
# ...

# %% [markdown]
# As you can see outliers are present in this dataset to remove the outliers we use Zscore method to remove the outlier

# %%
from scipy.stats import zscore
out_features=df[['Country Code','City','Longitude','Latitude','Average Cost for two','Currency','Has Table booking','Is delivering now','Price range','Aggregate rating','Votes']]
z=np.abs(zscore(out_features))
z
# Out:
#       Country Code      City  Longitude  Latitude  Average Cost for two  \
# 0         2.531111  0.228533   1.372269  1.025581              0.006154
# 1         2.531111  0.228533   1.371945  1.026647              0.000049
# 2         2.531111  0.142317   1.372975  1.024131              0.173743
# 3         2.531111  0.142317   1.372966  1.023775              0.018659
# 4         2.531111  0.142317   1.372991  1.023854              0.018659
# ...            ...       ...        ...       ...                   ...
# 9546      3.341718  2.659685   0.847685  1.378025              0.069428
# 9547      3.341718  2.659685   0.846144  1.376849              0.067878
# 9548      3.341718  2.659685   0.846305  1.381025              0.063845
# 9549      3.341718  2.659685   0.846272  1.381221              0.066947
# 9550      3.341718  2.659685   0.846513  1.374571              0.070979
#
#       Currency  Has Table booking  Is delivering now  Price range  \
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([   0,    1,    2, ..., 9549, 9550, 9550], dtype=int64),
#  array([5, 5, 5, ..., 5, 0, 5], dtype=int64))

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1.shape
# Out:
# (8408, 21)

# %%
print('old dataframe:',df.shape[0])
print('new dataframe:',df1.shape[0])
# Out:
# old dataframe: 9551
# new dataframe: 8408

# %%
print('datalosspercentage:',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# datalosspercentage: 11.967333263532614

# %% [markdown]
# As we can see there is less than 10% of data loss after removing the outliers so it is not considerable.

# %% [markdown]
# Checking Skewness

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Locality Verbose        -0.183064
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305923
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# dtype: float64

# %%
plt.figure(figsize=(20,25),facecolor='red')
num=1
for column in df:
    if num<=40:
        ax=plt.subplot(10,4,num)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
        
    num+=1
plt.show()

# %% [markdown]
# skewness more than+/- 0.5 will we treated
#
# object columns will no be treated

# %%
df['Votes']=np.cbrt(df['Votes'])

# %%
df['Country Code']=np.cbrt(df['Country Code'])

# %%
df['Longitude']=np.cbrt(df['Longitude'])

# %%
df['Latitude']=np.cbrt(df['Latitude'])

# %%
df['Average Cost for two']=np.cbrt(df['Average Cost for two'])

# %%
df['Aggregate rating']=np.cbrt(df['Aggregate rating'])

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             2.923867
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Locality Verbose        -0.183064
# Longitude               -2.928779
# Latitude                -3.856661
# Cuisines                -0.305923
# Average Cost for two     9.626632
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -1.272627
# Rating color             0.046009
# Rating text              0.431408
# Votes                    1.204920
# dtype: float64

# %%
df['Country Code']=np.sqrt(df['Country Code'])

# %%
df['Longitude']=np.sqrt(df['Longitude'])

# %%
df['Latitude']=np.sqrt(df['Latitude'])

# %%
df['Average Cost for two']=np.sqrt(df['Average Cost for two'])

# %%
df['Aggregate rating']=np.sqrt(df['Aggregate rating'])

# %%
df['Votes']=np.sqrt(df['Votes'])

# %%
df.skew()
# Out:
# Restaurant ID            0.061570
# Restaurant Name          0.044637
# Country Code             2.885565
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Locality Verbose        -0.183064
# Longitude               -3.827256
# Latitude                -3.858464
# Cuisines                -0.305923
# Average Cost for two     1.937457
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -1.306481
# Rating color             0.046009
# Rating text              0.431408
# Votes                   -0.399093
# dtype: float64

# %%
plt.figure(figsize=(20,25),facecolor='red')
num=1
for column in df:
    if num<=40:
        ax=plt.subplot(10,4,num)
        sns.distplot(df[column],color='b')
        plt.xlabel(column,fontsize=20)
        
    num+=1
plt.show()

# %% [markdown]
# Checking the Correlation b/w Target variable and Independent variable.

# %%
df.corr()
# Out:
#                       Restaurant ID  Restaurant Name  Country Code      City  \
# Restaurant ID              1.000000         0.003999      0.143706 -0.005844
# Restaurant Name            0.003999         1.000000      0.020468 -0.001399
# Country Code               0.143706         0.020468      1.000000 -0.177460
# City                      -0.005844        -0.001399     -0.177460  1.000000
# Address                    0.080615         0.000763     -0.209288 -0.019763
# Locality                   0.069511         0.004322     -0.120327  0.096444
# Locality Verbose           0.070102         0.004281     -0.117710  0.093142
# Longitude                 -0.162190         0.014692      0.014334  0.022009
# Latitude                  -0.142486         0.016275      0.084533  0.003615
# Cuisines                  -0.079240         0.051782     -0.139326  0.027176
# Average Cost for two      -0.185946         0.039675     -0.409832  0.021749
# ...

# %%
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,fmt='.1g',linecolor='black',annot=True,cmap='Blues_r')
plt.yticks(rotation=0)
plt.show()

# %%
df.drop(['Switch to order menu'],axis=1,inplace=True)

# %%
x=df1.drop(['Price range'],axis=1)
y=df1['Price range']

# %%
x.shape
# Out:
# (8408, 20)

# %%
y.shape
# Out:
# (8408,)

# %% [markdown]
# Feature scaling using StandardScaler method.

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#       Restaurant ID  Restaurant Name  Country Code      City   Address  \
# 0          1.074516         1.056536     20.155909  2.121012 -1.815318
# 1          1.074625        -0.845151     20.155909  2.121012 -1.441372
# 2          1.075928         0.786336     20.155909  2.121012 -0.990264
# 3          1.074518         0.640016     20.155909  2.121012 -1.078111
# 4          1.074499        -0.209385     20.155909  2.121012 -1.440185
# ...             ...              ...           ...       ...       ...
# 8403      -0.671283        -0.127577     -0.049994  3.027356  0.932091
# 8404      -0.671231         0.631602     -0.049994  3.027356  0.909535
# 8405      -0.671324         1.666124     -0.049994  3.027356  1.564434
# 8406      -0.671327        -0.585702     -0.049994  3.027356 -1.804238
# 8407       1.070894         1.705859     16.180977 -4.053462 -1.801072
#
#       Locality  Locality Verbose  Longitude  Latitude  Cuisines  \
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns
vif
# Out:
#     vif values              features
# 0     1.305538         Restaurant ID
# 1     1.008076       Restaurant Name
# 2     8.106827          Country Code
# 3     1.065811                  City
# 4     1.074336               Address
# 5   876.268322              Locality
# 6   876.556731      Locality Verbose
# 7     9.378279             Longitude
# 8     9.665455              Latitude
# 9     1.029444              Cuisines
# 10    1.874469  Average Cost for two
# 11    6.852157              Currency
# 12    1.691011     Has Table booking
# 13    1.171348   Has Online delivery
# 14         NaN     Is delivering now
# 15         NaN  Switch to order menu
# 16    2.026484      Aggregate rating
# 17    1.223560          Rating color
# 18    1.582370           Rating text
# 19    1.659717                 Votes

# %% [markdown]
# As we can seee there is multicorrelation present in theLocality,Locality Verbose,Is delivering now,Switch to order menu, .here has highly correlated and VIF value here is high so we can Drop this column.

# %%
x.drop('Locality',axis=1,inplace=True)

# %%
x.drop('Locality Verbose',axis=1,inplace=True)

# %%
x.drop('Is delivering now',axis=1,inplace=True)

# %%
x.drop('Switch to order menu',axis=1,inplace=True)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif=pd.DataFrame()
vif['vif values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif['features']=x.columns
vif
# Out:
#     vif values              features
# 0     1.304941         Restaurant ID
# 1     1.007935       Restaurant Name
# 2     8.106648          Country Code
# 3     1.058515                  City
# 4     1.057917               Address
# 5     9.373868             Longitude
# 6     9.661599              Latitude
# 7     1.028544              Cuisines
# 8     1.865859  Average Cost for two
# 9     6.850558              Currency
# 10    1.687280     Has Table booking
# 11    1.170964   Has Online delivery
# 12    2.008747      Aggregate rating
# 13    1.222093          Rating color
# 14    1.581050           Rating text
# 15    1.651680                 Votes

# %%
y.value_counts()
# Out:
# 1    4269
# 2    2775
# 3     997
# 4     367
# Name: Price range, dtype: int64

# %% [markdown]
# Here we can see that data is not balanced since it is a classification problem we will balance the data using Oversampling method.
#
# OverSampling here we use SMOTE method.

# %%
import sklearn
# !pip install imbalanced_learn
from imblearn.over_sampling import SMOTE
smt=SMOTE()

# %%
trainx,trainy=smt.fit_resample(x,y)

# %%
trainx.value_counts()
# Out:
# Restaurant ID  Restaurant Name  Country Code  City       Address    Longitude  Latitude   Cuisines   Average Cost for two  Currency  Has Table booking  Has Online delivery  Aggregate rating  Rating color  Rating text  Votes
# -0.983014      -1.564127        -0.049994      0.421615   0.657864   0.236622   0.313098   0.721135   2.040621             0.045263   2.647191           1.618955             0.078186         -0.780022     -1.015678     0.332696    1
#  1.044522      -1.046241        -0.049994     -1.730954  -1.204676   0.228217   0.289614   0.484002   1.809695             0.045263   2.647191           0.564491             1.075506         -1.506234      2.100363     0.543591    1
#  1.044052       0.708629        -0.049994      0.421615  -1.811763   0.235241   0.302029   0.597650   1.197950             0.045263   2.647191           1.618955             1.270432         -1.506234      2.100363     2.388664    1
# ...

# %%
trainy.value_counts()
# Out:
# 4    4269
# 2    4269
# 3    4269
# 1    4269
# Name: Price range, dtype: int64

# %%
trainy
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 17071    4
# 17072    4
# 17073    4
# 17074    4
# 17075    4
# Name: Price range, Length: 17076, dtype: int64

# %%
sns.countplot(trainy)
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# Model Bulding
#
# As you can see this is Classification problem in this we have catgerocial data present so we use Classification model here

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=0)

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
acc=accuracy_score(y_test,pred)
print(accuracy_score(y_test,pred))
# Out:
# 0.985731272294887

# %%
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,accuracy_score
from sklearn.model_selection import cross_val_score
RFC=RandomForestClassifier()
RFC.fit(x_train,y_train)
predRFC=RFC.predict(x_test)
print(accuracy_score(y_test,predRFC))
print(confusion_matrix(y_test,predRFC))
print(classification_report(y_test,predRFC))
# Out:
# 0.9861276258422513
# [[1280    4    0    0]
#  [   2  822    2    0]
#  [   1   12  285    3]
#  [   0    0   11  101]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1284
#            2       0.98      1.00      0.99       826
#            3       0.96      0.95      0.95       301
#            4       0.97      0.90      0.94       112
#
#     accuracy                           0.99      2523
#    macro avg       0.98      0.96      0.97      2523
# weighted avg       0.99      0.99      0.99      2523

# %%
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
print(accuracy_score(y_test,predsvc))
print(confusion_matrix(y_test,predsvc))
print(classification_report(y_test,predsvc))
# Out:
# 0.9349980182322631
# [[1259   25    0    0]
#  [  41  767   17    1]
#  [   0   52  242    7]
#  [   0    1   20   91]]
#               precision    recall  f1-score   support
#
#            1       0.97      0.98      0.97      1284
#            2       0.91      0.93      0.92       826
#            3       0.87      0.80      0.83       301
#            4       0.92      0.81      0.86       112
#
#     accuracy                           0.93      2523
#    macro avg       0.92      0.88      0.90      2523
# weighted avg       0.93      0.93      0.93      2523

# %%
ac=AdaBoostClassifier()
ac.fit(x_train,y_train)
predac=ac.predict(x_test)
print(accuracy_score(y_test,predac))
print(confusion_matrix(y_test,predac))
print(classification_report(y_test,predac))
# Out:
# 0.8406658739595719
# [[1284    0    0    0]
#  [  12  545  269    0]
#  [   0   12  289    0]
#  [   0    0  109    3]]
#               precision    recall  f1-score   support
#
#            1       0.99      1.00      1.00      1284
#            2       0.98      0.66      0.79       826
#            3       0.43      0.96      0.60       301
#            4       1.00      0.03      0.05       112
#
#     accuracy                           0.84      2523
#    macro avg       0.85      0.66      0.61      2523
# weighted avg       0.92      0.84      0.84      2523

# %%
bc=BaggingClassifier()
bc.fit(x_train,y_train)
predbc=bc.predict(x_test)
print(accuracy_score(y_test,predbc))
print(confusion_matrix(y_test,predbc))
print(classification_report(y_test,predbc))
# Out:
# 0.9869203329369798
# [[1281    3    0    0]
#  [   1  820    5    0]
#  [   0   10  290    1]
#  [   0    0   13   99]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1284
#            2       0.98      0.99      0.99       826
#            3       0.94      0.96      0.95       301
#            4       0.99      0.88      0.93       112
#
#     accuracy                           0.99      2523
#    macro avg       0.98      0.96      0.97      2523
# weighted avg       0.99      0.99      0.99      2523

# %%
et=ExtraTreesClassifier()
et.fit(x_train,y_train)
predet=et.predict(x_test)
print(accuracy_score(y_test,predet))
print(confusion_matrix(y_test,predet))
print(classification_report(y_test,predet))
# Out:
# 0.9587792310741181
# [[1269   15    0    0]
#  [  10  801   14    1]
#  [   0   36  259    6]
#  [   0    1   21   90]]
#               precision    recall  f1-score   support
#
#            1       0.99      0.99      0.99      1284
#            2       0.94      0.97      0.95       826
#            3       0.88      0.86      0.87       301
#            4       0.93      0.80      0.86       112
#
#     accuracy                           0.96      2523
#    macro avg       0.94      0.91      0.92      2523
# weighted avg       0.96      0.96      0.96      2523

# %%
from sklearn.tree import DecisionTreeClassifier
dc= DecisionTreeClassifier()
dc.fit(x_train,y_train)
preddc=dc.predict(x_test)
print(accuracy_score(y_test,preddc))
print(confusion_matrix(y_test,preddc))
print(classification_report(y_test,preddc))
# Out:
# 0.9892984542211652
# [[1280    4    0    0]
#  [   4  819    3    0]
#  [   0    4  289    8]
#  [   0    0    4  108]]
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1284
#            2       0.99      0.99      0.99       826
#            3       0.98      0.96      0.97       301
#            4       0.93      0.96      0.95       112
#
#     accuracy                           0.99      2523
#    macro avg       0.97      0.98      0.98      2523
# weighted avg       0.99      0.99      0.99      2523

# %% [markdown]
# Now we can check cross valdiation of all the model

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(RFC,x,y)
print(score)
print(score.mean())
print('difference b/w Accuracy_score and cross_val_score is:',accuracy_score(y_test,predRFC)-score.mean())
# Out:
# [0.93757432 0.96611177 0.99881094 1.         0.96966092]
# 0.9744315886939502
# difference b/w Accuracy_score and cross_val_score is: 0.011696037148301142

# %%
score=cross_val_score(ac,x,y)
print(score)
print(score.mean())
print('difference b/w Accuracy_score and cross_val_score is:',accuracy_score(y_test,predac)-score.mean())
# Out:
# [0.48810939 0.82758621 0.83769322 0.83759667 0.84057109]
# 0.7663113160234587
# difference b/w Accuracy_score and cross_val_score is: 0.07435455793611323

# %%
score=cross_val_score(bc,x,y)
print(score)
print(score.mean())
print('difference b/w Accuracy_score and cross_val_score is:',accuracy_score(y_test,predbc)-score.mean())
# Out:
# [0.58382878 0.95243757 1.         0.99940512 0.97144557]
# 0.9014234067400853
# difference b/w Accuracy_score and cross_val_score is: 0.08549692619689453

# %%
score=cross_val_score(svc,x,y)
print(score)
print(score.mean())
print('difference b/w Accuracy_score and cross_val_score is:',accuracy_score(y_test,predsvc)-score.mean())
# Out:
# [0.79904875 0.91498216 0.95838288 0.95657347 0.92266508]
# 0.9103304683172988
# difference b/w Accuracy_score and cross_val_score is: 0.024667549914964337

# %%
score=cross_val_score(et,x,y)
print(score)
print(score.mean())
print('difference b/w Accuracy_score and cross_val_score is:',accuracy_score(y_test,predet)-score.mean())
# Out:
# [0.58204518 0.93281807 0.98692033 0.9851279  0.94646044]
# 0.8866743862473573
# difference b/w Accuracy_score and cross_val_score is: 0.07210484482676083

# %%
score=cross_val_score(dc,x,y)
print(score)
print(score.mean())
print('difference b/w Accuracy_score and cross_val_score is:',accuracy_score(y_test,predet)-score.mean())
# Out:
# [0.58382878 0.9411415  1.         0.99881023 0.94467579]
# 0.8936912587420007
# difference b/w Accuracy_score and cross_val_score is: 0.06508797233211738

# %% [markdown]
# As we can see above all model Accuracy_score and crossval_score is less and score mean is 97% in model RandomForestClassifier() so this is the best model.
#
# Hyper parameter tunning

# %%
from sklearn.model_selection import  RandomizedSearchCV
param={'criterion':['gini','entropy']}
rscv= RandomizedSearchCV(RandomForestClassifier() ,param,cv=5)
rscv.fit(x_train,y_train)
rscv.best_params_
# Out:
# {'criterion': 'entropy'}

# %%
model=RandomForestClassifier(criterion='entropy')
model.fit(x_train,y_train)
pred=model.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 98.53349187475227

# %% [markdown]
# Plotting Roc and AUC curve

# %%
from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
fpr,tpr,thresholds =roc_curve(y_test,pred,pos_label=4)
roc_auc=metrics.auc(fpr,tpr)
display=metrics.RocCurveDisplay(fpr=fpr,tpr=tpr,roc_auc=roc_auc,estimator_name=model)
display.plot()

# %% [markdown]
# Save the model

# %%
import joblib
model=joblib.dump(model,'Zomato Restaurant')

# %%
import joblib
model=joblib.load('Zomato Restaurant')
prediction=model.predict(x_test)
prediction
# Out:
# array([1, 1, 2, ..., 2, 2, 1], dtype=int64)

# %%
a=np.array(y_test)
df=pd.DataFrame()
df['prediction']=prediction
df['original']=a
df
# Out:
#       prediction  original
# 0              1         1
# 1              1         1
# 2              2         2
# 3              1         1
# 4              4         4
# ...          ...       ...
# 2518           1         1
# 2519           2         2
# 2520           2         2
# 2521           2         2
# 2522           1         1
#
# [2523 rows x 2 columns]
